# %%
import pymongo
import pprint

# %%
client = pymongo.MongoClient('mongodb://analytics-student:analytics-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')

# %%
trips = client.citibike.trips

# %%
# Replace XXXX with your aggregation pipeline to answer the question:
# Citibike trips that start at station id 279 end most frequently at what station id?
pipeline = [
    {
        '$match': {'start station id': 279}
    },
    {
        '$sortByCount': "$end station id"
    }
]

# %%
# print the results
for trip in trips.aggregate(pipeline):
    pprint.pprint(trip)
# Out:
# {'_id': ObjectId('572bb8232b288919b68af878'),
#  'bikeid': 19555,
#  'birth year': 1957,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 2, 11, 57, 41),
#  'stop time': datetime.datetime(2016, 1, 2, 12, 1, 36),
#  'tripduration': 234,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8222b288919b68aca52'),
#  'bikeid': 14578,
#  'birth year': 1958,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 1, 11, 34, 27),
#  'stop time': datetime.datetime(2016, 1, 1, 11, 44, 54),
#  'tripduration': 627,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8242b288919b68bcf53'),
#  'bikeid': 16018,
#  'birth year': 1967,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 5, 15, 33, 32),
#  'stop time': datetime.datetime(2016, 1, 5, 16, 8, 56),
#  'tripduration': 2123,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8242b288919b68c1f42'),
#  'bikeid': 23519,
#  'birth year': 1960,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 6, 14, 13, 11),
#  'stop time': datetime.datetime(2016, 1, 6, 14, 37, 50),
#  'tripduration': 1479,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8242b288919b68c24c0'),
#  'bikeid': 16018,
#  'birth year': 1967,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 6, 15, 21, 52),
#  'stop time': datetime.datetime(2016, 1, 6, 15, 59, 23),
#  'tripduration': 2250,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8252b288919b68c7b40'),
#  'bikeid': 14811,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 7, 12, 1, 26),
#  'stop time': datetime.datetime(2016, 1, 7, 12, 3, 52),
#  'tripduration': 146,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8252b288919b68ca832'),
#  'bikeid': 18031,
#  'birth year': 1960,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 7, 18, 36, 27),
#  'stop time': datetime.datetime(2016, 1, 7, 18, 58, 29),
#  'tripduration': 1322,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8252b288919b68ca843'),
#  'bikeid': 17369,
#  'birth year': 1973,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 7, 18, 36, 49),
#  'stop time': datetime.datetime(2016, 1, 7, 18, 57, 51),
#  'tripduration': 1262,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8262b288919b68d410c'),
#  'bikeid': 16562,
#  'birth year': 1957,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 9, 11, 10, 29),
#  'stop time': datetime.datetime(2016, 1, 9, 11, 25, 18),
#  'tripduration': 888,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8272b288919b68d8919'),
#  'bikeid': 17389,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 10, 11, 19, 9),
#  'stop time': datetime.datetime(2016, 1, 10, 11, 59, 12),
#  'tripduration': 2403,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8262b288919b68d05fa'),
#  'bikeid': 18344,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 8, 16, 51, 31),
#  'stop time': datetime.datetime(2016, 1, 8, 16, 56, 32),
#  'tripduration': 300,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8272b288919b68d891d'),
#  'bikeid': 14645,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 10, 11, 19, 21),
#  'stop time': datetime.datetime(2016, 1, 10, 11, 59, 36),
#  'tripduration': 2414,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8272b288919b68de013'),
#  'bikeid': 21578,
#  'birth year': 1958,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 11, 13, 15, 12),
#  'stop time': datetime.datetime(2016, 1, 11, 13, 28, 42),
#  'tripduration': 809,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8272b288919b68d7616'),
#  'bikeid': 17375,
#  'birth year': 1957,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 9, 19, 24, 59),
#  'stop time': datetime.datetime(2016, 1, 9, 19, 37, 8),
#  'tripduration': 729,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8292b288919b68eab8c'),
#  'bikeid': 22421,
#  'birth year': 1978,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 13, 17, 23, 50),
#  'stop time': datetime.datetime(2016, 1, 13, 17, 58, 30),
#  'tripduration': 2079,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8292b288919b68ecd45'),
#  'bikeid': 15446,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 14, 7, 20, 39),
#  'stop time': datetime.datetime(2016, 1, 14, 7, 24, 1),
#  'tripduration': 201,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb82a2b288919b68f843d'),
#  'bikeid': 17318,
#  'birth year': 1957,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 15, 19, 9, 47),
#  'stop time': datetime.datetime(2016, 1, 15, 19, 23, 18),
#  'tripduration': 811,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb82b2b288919b690020b'),
#  'bikeid': 16395,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 17, 15, 55, 29),
#  'stop time': datetime.datetime(2016, 1, 17, 16, 50, 14),
#  'tripduration': 3285,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb82b2b288919b6900209'),
#  'bikeid': 16204,
#  'birth year': 1973,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 17, 15, 55, 13),
#  'stop time': datetime.datetime(2016, 1, 17, 16, 50, 9),
#  'tripduration': 3296,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb82b2b288919b6900218'),
#  'bikeid': 24769,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 17, 15, 56, 22),
#  'stop time': datetime.datetime(2016, 1, 17, 16, 50, 13),
#  'tripduration': 3230,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb82b2b288919b6900212'),
#  'bikeid': 15166,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 17, 15, 56, 5),
#  'stop time': datetime.datetime(2016, 1, 17, 16, 50, 30),
#  'tripduration': 3264,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb82d2b288919b6910968'),
#  'bikeid': 22958,
#  'birth year': 1960,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 21, 13, 53, 4),
#  'stop time': datetime.datetime(2016, 1, 21, 14, 13, 45),
#  'tripduration': 1240,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb82e2b288919b691b755'),
#  'bikeid': 15681,
#  'birth year': 1957,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 28, 12, 7, 30),
#  'stop time': datetime.datetime(2016, 1, 28, 12, 22, 13),
#  'tripduration': 883,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb82f2b288919b6924a71'),
#  'bikeid': 24765,
#  'birth year': 1983,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 31, 8, 34, 53),
#  'stop time': datetime.datetime(2016, 1, 31, 8, 48, 11),
#  'tripduration': 797,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8302b288919b6927227'),
#  'bikeid': 20211,
#  'birth year': 1969,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 31, 16, 41, 5),
#  'stop time': datetime.datetime(2016, 1, 31, 16, 49, 26),
#  'tripduration': 501,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8302b288919b692bbb3'),
#  'bikeid': 19335,
#  'birth year': 1957,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 1, 15, 46, 19),
#  'stop time': datetime.datetime(2016, 2, 1, 16, 9, 1),
#  'tripduration': 1362,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8302b288919b6927604'),
#  'bikeid': 16662,
#  'birth year': 1967,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 1, 31, 17, 21, 48),
#  'stop time': datetime.datetime(2016, 1, 31, 17, 45, 41),
#  'tripduration': 1432,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8322b288919b693b02a'),
#  'bikeid': 15848,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 4, 9, 37, 42),
#  'stop time': datetime.datetime(2016, 2, 4, 9, 40, 33),
#  'tripduration': 171,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8332b288919b69434f5'),
#  'bikeid': 21070,
#  'birth year': 1979,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 5, 23, 46, 16),
#  'stop time': datetime.datetime(2016, 2, 5, 23, 51, 19),
#  'tripduration': 302,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8342b288919b694a7e6'),
#  'bikeid': 21078,
#  'birth year': 1958,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 7, 16, 52, 35),
#  'stop time': datetime.datetime(2016, 2, 7, 17, 8, 37),
#  'tripduration': 962,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8352b288919b694e452'),
#  'bikeid': 17615,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 8, 16, 0, 31),
#  'stop time': datetime.datetime(2016, 2, 8, 16, 2, 28),
#  'tripduration': 117,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8362b288919b6955615'),
#  'bikeid': 17406,
#  'birth year': 1983,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 9, 20, 9, 10),
#  'stop time': datetime.datetime(2016, 2, 9, 20, 17, 19),
#  'tripduration': 489,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8362b288919b6955667'),
#  'bikeid': 19175,
#  'birth year': 1900,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 9, 20, 13, 19),
#  'stop time': datetime.datetime(2016, 2, 9, 20, 17, 14),
#  'tripduration': 234,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8392b288919b69718c8'),
#  'bikeid': 19591,
#  'birth year': 1994,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 18, 0, 59, 30),
#  'stop time': datetime.datetime(2016, 2, 18, 1, 5, 12),
#  'tripduration': 342,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb83b2b288919b697e092'),
#  'bikeid': 17352,
#  'birth year': 1981,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 20, 12, 45, 47),
#  'stop time': datetime.datetime(2016, 2, 20, 13, 22, 19),
#  'tripduration': 2192,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb83b2b288919b697ee2c'),
#  'bikeid': 17913,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 20, 14, 24, 45),
#  'stop time': datetime.datetime(2016, 2, 20, 14, 29, 44),
#  'tripduration': 298,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb83b2b288919b697ed98'),
#  'bikeid': 20774,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 20, 14, 20, 35),
#  'stop time': datetime.datetime(2016, 2, 20, 14, 48, 10),
#  'tripduration': 1655,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb83b2b288919b697eccc'),
#  'bikeid': 17913,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 20, 14, 14, 51),
#  'stop time': datetime.datetime(2016, 2, 20, 14, 20, 26),
#  'tripduration': 335,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb83b2b288919b697c77b'),
#  'bikeid': 14657,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 20, 4, 15, 8),
#  'stop time': datetime.datetime(2016, 2, 20, 4, 27, 2),
#  'tripduration': 714,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb83b2b288919b697f4b9'),
#  'bikeid': 15713,
#  'birth year': 1959,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 20, 15, 11, 42),
#  'stop time': datetime.datetime(2016, 2, 20, 15, 13, 7),
#  'tripduration': 85,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb83b2b288919b697f87c'),
#  'bikeid': 14718,
#  'birth year': 1958,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 20, 15, 36, 27),
#  'stop time': datetime.datetime(2016, 2, 20, 15, 37, 50),
#  'tripduration': 82,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb83b2b288919b6981e35'),
#  'bikeid': 22452,
#  'birth year': 1960,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 20, 21, 10, 21),
#  'stop time': datetime.datetime(2016, 2, 20, 21, 18, 2),
#  'tripduration': 460,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb83c2b288919b69847bd'),
#  'bikeid': 19051,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 21, 13, 43, 36),
#  'stop time': datetime.datetime(2016, 2, 21, 14, 7, 6),
#  'tripduration': 1409,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb83c2b288919b69844ca'),
#  'bikeid': 23080,
#  'birth year': 1973,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 21, 13, 21, 43),
#  'stop time': datetime.datetime(2016, 2, 21, 13, 31, 11),
#  'tripduration': 567,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb83c2b288919b69871c7'),
#  'bikeid': 14772,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 21, 22, 29, 5),
#  'stop time': datetime.datetime(2016, 2, 21, 22, 40, 42),
#  'tripduration': 696,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb83f2b288919b699cb03'),
#  'bikeid': 23815,
#  'birth year': 1963,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 26, 12, 0, 41),
#  'stop time': datetime.datetime(2016, 2, 26, 12, 5, 30),
#  'tripduration': 288,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8402b288919b69a81b4'),
#  'bikeid': 19258,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 28, 15, 59, 3),
#  'stop time': datetime.datetime(2016, 2, 28, 16, 11, 42),
#  'tripduration': 759,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8402b288919b69a685a'),
#  'bikeid': 19910,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 28, 13, 39, 20),
#  'stop time': datetime.datetime(2016, 2, 28, 14, 21, 3),
#  'tripduration': 2502,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8402b288919b69a684a'),
#  'bikeid': 23362,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 28, 13, 38, 53),
#  'stop time': datetime.datetime(2016, 2, 28, 14, 22, 1),
#  'tripduration': 2587,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8402b288919b69a6dbe'),
#  'bikeid': 18741,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 28, 14, 10, 22),
#  'stop time': datetime.datetime(2016, 2, 28, 14, 34, 5),
#  'tripduration': 1423,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8402b288919b69a721d'),
#  'bikeid': 22564,
#  'birth year': 1973,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 28, 14, 34, 38),
#  'stop time': datetime.datetime(2016, 2, 28, 14, 46, 11),
#  'tripduration': 692,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8412b288919b69aef63'),
#  'bikeid': 19260,
#  'birth year': 1972,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 2, 29, 17, 36, 28),
#  'stop time': datetime.datetime(2016, 2, 29, 17, 37, 38),
#  'tripduration': 70,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d41e2'),
#  'bikeid': 24056,
#  'birth year': 1957,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 11, 14, 21, 27),
#  'stop time': datetime.datetime(2016, 3, 11, 14, 58, 15),
#  'tripduration': 2208,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d41e1'),
#  'bikeid': 23712,
#  'birth year': 1962,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 11, 14, 20, 36),
#  'stop time': datetime.datetime(2016, 3, 11, 14, 58, 8),
#  'tripduration': 2251,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d42d1'),
#  'bikeid': 20335,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 14, 0, 47, 47),
#  'stop time': datetime.datetime(2016, 3, 14, 0, 50, 52),
#  'tripduration': 184,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d42b6'),
#  'bikeid': 19557,
#  'birth year': 1975,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 13, 16, 55, 30),
#  'stop time': datetime.datetime(2016, 3, 13, 16, 56, 46),
#  'tripduration': 75,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d443a'),
#  'bikeid': 18928,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 19, 15, 54, 35),
#  'stop time': datetime.datetime(2016, 3, 19, 16, 20, 15),
#  'tripduration': 1540,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4324'),
#  'bikeid': 23719,
#  'birth year': 1972,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 16, 8, 24, 31),
#  'stop time': datetime.datetime(2016, 3, 16, 8, 33, 14),
#  'tripduration': 523,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d43f8'),
#  'bikeid': 23752,
#  'birth year': 1960,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 18, 14, 9, 30),
#  'stop time': datetime.datetime(2016, 3, 18, 14, 22, 12),
#  'tripduration': 761,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4463'),
#  'bikeid': 19094,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 21, 3, 3, 30),
#  'stop time': datetime.datetime(2016, 3, 21, 3, 25, 39),
#  'tripduration': 1329,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4219'),
#  'bikeid': 23854,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 12, 10, 26, 30),
#  'stop time': datetime.datetime(2016, 3, 12, 11, 0, 10),
#  'tripduration': 2020,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d42cf'),
#  'bikeid': 20626,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 14, 0, 42, 7),
#  'stop time': datetime.datetime(2016, 3, 14, 0, 46, 1),
#  'tripduration': 233,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d4314'),
#  'bikeid': 15634,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 15, 20, 29, 46),
#  'stop time': datetime.datetime(2016, 3, 15, 20, 39, 50),
#  'tripduration': 603,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4370'),
#  'bikeid': 22365,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 16, 22, 45, 51),
#  'stop time': datetime.datetime(2016, 3, 16, 23, 13, 24),
#  'tripduration': 1653,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4225'),
#  'bikeid': 22523,
#  'birth year': 1965,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 12, 12, 39, 20),
#  'stop time': datetime.datetime(2016, 3, 12, 12, 40, 32),
#  'tripduration': 71,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d439c'),
#  'bikeid': 23957,
#  'birth year': 1960,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 17, 14, 9, 34),
#  'stop time': datetime.datetime(2016, 3, 17, 14, 22, 48),
#  'tripduration': 793,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4402'),
#  'bikeid': 23752,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 18, 16, 40, 23),
#  'stop time': datetime.datetime(2016, 3, 18, 17, 13, 31),
#  'tripduration': 1987,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4434'),
#  'bikeid': 19278,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 19, 13, 41, 39),
#  'stop time': datetime.datetime(2016, 3, 19, 13, 43, 21),
#  'tripduration': 101,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d4440'),
#  'bikeid': 23847,
#  'birth year': 1980,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 19, 18, 49),
#  'stop time': datetime.datetime(2016, 3, 19, 19, 19, 25),
#  'tripduration': 1825,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d42a0'),
#  'bikeid': 24342,
#  'birth year': 1951,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 13, 15, 48, 55),
#  'stop time': datetime.datetime(2016, 3, 13, 16, 3, 36),
#  'tripduration': 880,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d42ae'),
#  'bikeid': 17817,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 13, 16, 33, 10),
#  'stop time': datetime.datetime(2016, 3, 13, 16, 47, 18),
#  'tripduration': 848,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d42d0'),
#  'bikeid': 19870,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 14, 0, 45, 23),
#  'stop time': datetime.datetime(2016, 3, 14, 0, 49, 8),
#  'tripduration': 224,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d44ca'),
#  'bikeid': 15395,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 22, 18, 47, 28),
#  'stop time': datetime.datetime(2016, 3, 22, 19, 10, 47),
#  'tripduration': 1398,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d44db'),
#  'bikeid': 21404,
#  'birth year': 1990,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 22, 22, 30, 43),
#  'stop time': datetime.datetime(2016, 3, 22, 22, 56, 45),
#  'tripduration': 1562,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4524'),
#  'bikeid': 19233,
#  'birth year': 1968,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 23, 17, 44, 8),
#  'stop time': datetime.datetime(2016, 3, 23, 17, 47, 17),
#  'tripduration': 188,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4503'),
#  'bikeid': 20707,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 23, 12, 21, 48),
#  'stop time': datetime.datetime(2016, 3, 23, 12, 22, 52),
#  'tripduration': 63,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d446e'),
#  'bikeid': 18872,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
# ...
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 26, 17, 4, 15),
#  'stop time': datetime.datetime(2016, 3, 26, 18, 7, 47),
#  'tripduration': 3811,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d4671'),
#  'bikeid': 15530,
#  'birth year': 1974,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 26, 20, 51, 6),
#  'stop time': datetime.datetime(2016, 3, 26, 20, 53, 15),
#  'tripduration': 129,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d47e8'),
#  'bikeid': 19076,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 23, 17, 22),
#  'stop time': datetime.datetime(2016, 3, 31, 23, 20, 6),
#  'tripduration': 163,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d45d1'),
#  'bikeid': 20553,
#  'birth year': 1967,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 25, 17, 1, 21),
#  'stop time': datetime.datetime(2016, 3, 25, 17, 24, 52),
#  'tripduration': 1411,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4675'),
#  'bikeid': 15530,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 26, 22, 42, 12),
#  'stop time': datetime.datetime(2016, 3, 27, 11, 9, 48),
#  'tripduration': 44856,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d478b'),
#  'bikeid': 19752,
#  'birth year': 1963,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 9, 14, 47),
#  'stop time': datetime.datetime(2016, 3, 31, 9, 24, 25),
#  'tripduration': 578,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4696'),
#  'bikeid': 18662,
#  'birth year': 1967,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 27, 14, 58, 27),
#  'stop time': datetime.datetime(2016, 3, 27, 15, 9, 26),
#  'tripduration': 658,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d47dc'),
#  'bikeid': 21177,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 20, 31, 20),
#  'stop time': datetime.datetime(2016, 3, 31, 21, 49, 28),
#  'tripduration': 4688,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d479e'),
#  'bikeid': 15361,
#  'birth year': 1962,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 13, 31, 59),
#  'stop time': datetime.datetime(2016, 3, 31, 14, 6, 19),
#  'tripduration': 2060,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d47d9'),
#  'bikeid': 15145,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 20, 30, 20),
#  'stop time': datetime.datetime(2016, 3, 31, 21, 50, 3),
#  'tripduration': 4783,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d47da'),
#  'bikeid': 16722,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 20, 30, 20),
#  'stop time': datetime.datetime(2016, 3, 31, 21, 49, 46),
#  'tripduration': 4765,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d4796'),
#  'bikeid': 16970,
#  'birth year': 1976,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 12, 4, 32),
#  'stop time': datetime.datetime(2016, 3, 31, 12, 9, 12),
#  'tripduration': 279,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d47a1'),
#  'bikeid': 19318,
#  'birth year': 1975,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 14, 18, 39),
#  'stop time': datetime.datetime(2016, 3, 31, 14, 19, 42),
#  'tripduration': 63,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d46cd'),
#  'bikeid': 18662,
#  'birth year': 1985,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 28, 17, 21, 5),
#  'stop time': datetime.datetime(2016, 3, 28, 17, 22, 20),
#  'tripduration': 75,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d47d4'),
#  'bikeid': 19003,
#  'birth year': 1963,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 19, 46, 56),
#  'stop time': datetime.datetime(2016, 3, 31, 19, 56, 46),
#  'tripduration': 590,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d474f'),
#  'bikeid': 15404,
#  'birth year': 1962,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 30, 14, 16, 13),
#  'stop time': datetime.datetime(2016, 3, 30, 14, 49, 31),
#  'tripduration': 1998,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4667'),
#  'bikeid': 19877,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 26, 17, 14, 29),
#  'stop time': datetime.datetime(2016, 3, 26, 17, 16, 26),
#  'tripduration': 116,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d47bb'),
#  'bikeid': 21578,
#  'birth year': 1967,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 17, 9, 14),
#  'stop time': datetime.datetime(2016, 3, 31, 17, 41, 20),
#  'tripduration': 1925,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d46b6'),
#  'bikeid': 24343,
#  'birth year': 1963,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 28, 11, 11, 36),
#  'stop time': datetime.datetime(2016, 3, 28, 11, 24, 35),
#  'tripduration': 779,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d4661'),
#  'bikeid': 19324,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 26, 17, 4, 18),
#  'stop time': datetime.datetime(2016, 3, 26, 17, 8, 20),
#  'tripduration': 242,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d46c9'),
#  'bikeid': 18779,
#  'birth year': 1965,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 2,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 28, 17, 13, 31),
#  'stop time': datetime.datetime(2016, 3, 28, 17, 15, 30),
#  'tripduration': 119,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d47db'),
#  'bikeid': 17572,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 31, 20, 30, 32),
#  'stop time': datetime.datetime(2016, 3, 31, 21, 49, 34),
#  'tripduration': 4742,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d4699'),
#  'bikeid': 18662,
#  'birth year': 1984,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 27, 16, 22, 2),
#  'stop time': datetime.datetime(2016, 3, 27, 16, 29, 24),
#  'tripduration': 441,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d45f8'),
#  'bikeid': 14646,
#  'birth year': 1989,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 25, 21, 39, 53),
#  'stop time': datetime.datetime(2016, 3, 25, 22, 8, 6),
#  'tripduration': 1693,
#  'usertype': 'Subscriber'}
# {'_id': ObjectId('572bb8452b288919b69d466e'),
#  'bikeid': 15145,
#  'birth year': '',
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 0,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 26, 18, 57, 49),
#  'stop time': datetime.datetime(2016, 3, 26, 19, 33, 41),
#  'tripduration': 2151,
#  'usertype': 'Customer'}
# {'_id': ObjectId('572bb8452b288919b69d46be'),
#  'bikeid': 21690,
#  'birth year': 1960,
#  'end station id': 279,
#  'end station location': {'coordinates': [-74.00167, 40.707873],
#                           'type': 'Point'},
#  'end station name': 'Peck Slip & Front St',
#  'gender': 1,
#  'start station id': 279,
#  'start station location': {'coordinates': [-74.00167, 40.707873],
#                             'type': 'Point'},
#  'start station name': 'Peck Slip & Front St',
#  'start time': datetime.datetime(2016, 3, 28, 15, 56, 9),
#  'stop time': datetime.datetime(2016, 3, 28, 16, 9, 42),
#  'tripduration': 813,
#  'usertype': 'Subscriber'}
